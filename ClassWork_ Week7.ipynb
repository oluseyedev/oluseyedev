# %% [markdown]
# <a href="https://colab.research.google.com/github/oluseyedev/oluseyedev/blob/main/ClassWork_%20Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
DF_train=pd.read_csv('/content/sample_data/california_housing_train.csv')
DF_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
DF_train.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
DF_train_final=DF_train.loc[:,['housing_median_age','total_rooms','total_bedrooms','population','households','median_income','median_house_value']]
DF_train_final
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    15.0       5612.0          1283.0      1015.0
# 1                    19.0       7650.0          1901.0      1129.0
# 2                    17.0        720.0           174.0       333.0
# 3                    14.0       1501.0           337.0       515.0
# 4                    20.0       1454.0           326.0       624.0
# ...                   ...          ...             ...         ...
# 16995                52.0       2217.0           394.0       907.0
# 16996                36.0       2349.0           528.0      1194.0
# 16997                17.0       2677.0           531.0      1244.0
# 16998                19.0       2672.0           552.0      1298.0
# 16999                52.0       1820.0           300.0       806.0
#
#        households  median_income  median_house_value
# 0           472.0         1.4936             66900.0
# 1           463.0         1.8200             80100.0
# ...

# %%
x_train=DF_train_final.loc[:,['housing_median_age','total_rooms','total_bedrooms','population','households','median_income']]

x_train
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    15.0       5612.0          1283.0      1015.0
# 1                    19.0       7650.0          1901.0      1129.0
# 2                    17.0        720.0           174.0       333.0
# 3                    14.0       1501.0           337.0       515.0
# 4                    20.0       1454.0           326.0       624.0
# ...                   ...          ...             ...         ...
# 16995                52.0       2217.0           394.0       907.0
# 16996                36.0       2349.0           528.0      1194.0
# 16997                17.0       2677.0           531.0      1244.0
# 16998                19.0       2672.0           552.0      1298.0
# 16999                52.0       1820.0           300.0       806.0
#
#        households  median_income
# 0           472.0         1.4936
# 1           463.0         1.8200
# 2           117.0         1.6509
# ...

# %%
y_train=DF_train_final.loc[:,['median_house_value']]

y_train
# Out:
#        median_house_value
# 0                 66900.0
# 1                 80100.0
# 2                 85700.0
# 3                 73400.0
# 4                 65500.0
# ...                   ...
# 16995            111400.0
# 16996             79000.0
# 16997            103600.0
# 16998             85800.0
# 16999             94600.0
#
# [17000 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
model_LR=LinearRegression()
model_LR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
DF_test=pd.read_csv('/content/sample_data/california_housing_test.csv')
DF_test
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
x_test=DF_test.loc[:,['housing_median_age','total_rooms','total_bedrooms','population','households','median_income']]

x_test
# Out:
#       housing_median_age  total_rooms  total_bedrooms  population  households  \
# 0                   27.0       3885.0           661.0      1537.0       606.0
# 1                   43.0       1510.0           310.0       809.0       277.0
# 2                   27.0       3589.0           507.0      1484.0       495.0
# 3                   28.0         67.0            15.0        49.0        11.0
# 4                   19.0       1241.0           244.0       850.0       237.0
# ...                  ...          ...             ...         ...         ...
# 2995                23.0       1450.0           642.0      1258.0       607.0
# 2996                27.0       5257.0          1082.0      3496.0      1036.0
# 2997                10.0        956.0           201.0       693.0       220.0
# 2998                40.0         96.0            14.0        46.0        14.0
# 2999                42.0       1765.0           263.0       753.0       260.0
#
#       median_income
# ...

# %%
y_test=DF_test.loc[:,['median_house_value']]

y_test
# Out:
#       median_house_value
# 0               344700.0
# 1               176500.0
# 2               270500.0
# 3               330000.0
# 4                81700.0
# ...                  ...
# 2995            225000.0
# 2996            237200.0
# 2997             62000.0
# 2998            162500.0
# 2999            500001.0
#
# [3000 rows x 1 columns]

# %%
y_predict=model_LR.predict(x_test)

# %%
y_predict
# Out:
# array([[332098.0230497 ],
#        [213719.81431062],
#        [271260.04407687],
#        ...,
#        [ 85797.18665274],
#        [184332.1842798 ],
#        [440203.98512845]])

# %%
from sklearn.linear_model import LinearRegression
model_LR=LinearRegression()
model_LR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict=model_LR.predict(x_test)

# %%
from sklearn import metrics
import numpy as np
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# Mean Squared Error:  5808966246.7101965
# Mean Absolute Error:  55396.294616990475
# Root Mean Squared Error:  76216.57461937131

# %%
from sklearn.svm import SVR
model = SVR(kernel = 'rbf')
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
y_predict=model.predict(x_test)

# %%
from sklearn import metrics
import numpy as np
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# Mean Squared Error:  13427202411.670599
# Mean Absolute Error:  86544.68824545684
# Root Mean Squared Error:  115875.80598067312

# %%
from sklearn.svm import SVR
model = SVR(kernel = 'linear')
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='linear')

# %%
y_predict=model.predict(x_test)

# %%
from sklearn import metrics
import numpy as np
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# Mean Squared Error:  8674170898.750322
# Mean Absolute Error:  69888.68160817654
# Root Mean Squared Error:  93135.2290959244

# %%
from sklearn.svm import SVR
model = SVR(kernel = 'poly')
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='poly')

# %%
y_predict=model.predict(x_test)

# %%
from sklearn import metrics
import numpy as np
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# Mean Squared Error:  13431609355.492432
# Mean Absolute Error:  86582.30293130188
# Root Mean Squared Error:  115894.82022718889

# %%
import pandas as pd
df_train=pd.read_csv('/content/sample_data/california_housing_test.csv')
df_test=pd.read_csv('/content/sample_data/california_housing_test.csv')

x_train=df_train.loc[:,['housing_median_age','total_rooms','total_bedrooms','population','households','median_income']]
y_train=df_train.loc[:,['median_house_value']]
x_test=df_test.loc[:,['housing_median_age','total_rooms','total_bedrooms','population','households','median_income']]

y_test=df_test.loc[:,['median_house_value']]

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_predict=model.predict(x_test)

# %%
from sklearn import metrics
import numpy as np

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# Mean Squared Error:  0.0
# Mean Absolute Error:  0.0
# Root Mean Squared Error:  0.0

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 100)
model.fit(x_train, y_train)
# Out:
# <ipython-input-46-4632b006e0c8>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train, y_train)
# RandomForestRegressor()

# %%
y_predict=model.predict(x_test)

# %%
from sklearn import metrics
import numpy as np

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# Mean Squared Error:  687221338.401028
# Mean Absolute Error:  19210.422273333334
# Root Mean Squared Error:  26214.906797488868

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 200)
model.fit(x_train, y_train)
# Out:
# <ipython-input-49-36fc5a4f9efd>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train, y_train)
# RandomForestRegressor(n_estimators=200)

# %%
y_predict=model.predict(x_test)

# %%
from sklearn import metrics
import numpy as np

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# Mean Squared Error:  687484526.915276
# Mean Absolute Error:  19024.190213333335
# Root Mean Squared Error:  26219.9261424451

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 500)
model.fit(x_train, y_train)
# Out:
# <ipython-input-54-40d56f3e9a3e>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train, y_train)
# RandomForestRegressor(n_estimators=500)

# %%
y_predict=model.predict(x_test)

# %%
from sklearn import metrics
import numpy as np

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# Mean Squared Error:  675717164.8857981
# Mean Absolute Error:  18974.023864
# Root Mean Squared Error:  25994.560294142273

# %%
y_predict=model.predict(x_test)

# %%
print('MSE of SVR(LINEAR)', 93135.2290959244 )
print('MSE of SVR(RBF)', 115875.80598067312 )
print('MSE of SVR(Poly)', 115894.82022718889 )
print('MSE of LLINEAR)', 76216.57461937131 )
# Out:
# MSE of SVR(LINEAR) 93135.2290959244
# MSE of SVR(RBF) 115875.80598067312
# MSE of SVR(Poly) 115894.82022718889
# MSE of LLINEAR) 76216.57461937131

# %%
MSE_SVR_LINEAR = 93135.2290959244
MSE_SVR_RBF = 115875.80598067312
MSE_SVR_POLY = 115894.82022718889
MSE_LINEAR = 76216.57461937131

# %%
methods = [ ' SVR Linear', 'SVR Polynomials', 'SVR BRF', 'Linear']

# %%
import matplotlib.pyplot as plt

mse_values = [MSE_SVR_LINEAR, MSE_SVR_RBF, MSE_SVR_POLY, MSE_LINEAR]

plt.bar(methods, mse_values)

plt.xlabel("Methods")

plt.ylabel("mse_values")

plt.title("Mean Squared Error (MSE) for Different Methods")

plt.show()
